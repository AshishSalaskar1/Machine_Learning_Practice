# %%
import  numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from collections import Counter
from sklearn import datasets
# from sklearn import cross_validation

# %%
X,y = datasets.make_circles()

# %% [markdown]
# ### Simple Cross Validation

# %%
# split into train and test
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3)

# split training dataset into cross_validation_train/test
X_tr, X_cv, y_tr, y_cv = train_test_split(X_train,y_train,test_size=0.3)

# %% [markdown]
# ### CV Accuracies

# %%
for i in range(1,30,2):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_tr,y_tr)
    pred = knn.predict(X_cv)
    
    acc = accuracy_score(y_cv,pred,normalize=True) * float(100)
    print("CV Accuracy for k= %d is %d %%" % (i,acc))
# Out:
# CV Accuracy for k= 1 is 80 %
# CV Accuracy for k= 3 is 57 %
# CV Accuracy for k= 5 is 52 %
# CV Accuracy for k= 7 is 52 %
# CV Accuracy for k= 9 is 38 %
# CV Accuracy for k= 11 is 38 %
# CV Accuracy for k= 13 is 42 %
# CV Accuracy for k= 15 is 42 %
# CV Accuracy for k= 17 is 42 %
# CV Accuracy for k= 19 is 47 %
# CV Accuracy for k= 21 is 52 %
# CV Accuracy for k= 23 is 52 %
# CV Accuracy for k= 25 is 52 %
# CV Accuracy for k= 27 is 42 %
# CV Accuracy for k= 29 is 57 %

# %% [markdown]
# ### Test Accuracies

# %%
for i in range(1,30,2):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_tr,y_tr)
    pred = knn.predict(X_test)
    
    acc = accuracy_score(y_test,pred,normalize=True) * float(100)
    print("Test Accuracy for k= %d is %d %%" % (i,acc))
# Out:
# Test Accuracy for k= 1 is 70 %
# Test Accuracy for k= 3 is 50 %
# Test Accuracy for k= 5 is 46 %
# Test Accuracy for k= 7 is 46 %
# Test Accuracy for k= 9 is 46 %
# Test Accuracy for k= 11 is 40 %
# Test Accuracy for k= 13 is 33 %
# Test Accuracy for k= 15 is 36 %
# Test Accuracy for k= 17 is 36 %
# Test Accuracy for k= 19 is 43 %
# Test Accuracy for k= 21 is 50 %
# Test Accuracy for k= 23 is 46 %
# Test Accuracy for k= 25 is 30 %
# Test Accuracy for k= 27 is 46 %
# Test Accuracy for k= 29 is 46 %

# %% [markdown]
# ### 10 - Fold Cross Validation

# %%
#list of odd number of K
myList = list(range(0,50))
nbrs = list(filter(lambda x: x%2 !=0 ,myList))

cv_scores = []

#perform 10-fold cv
for k in nbrs:
    knn = KNeighborsClassifier(n_neighbors=k)
    scores = cross_val_score(knn,X_train,y_train,scoring="accuracy",cv=10)
    # average of 10 scores 
    cv_scores.append(scores.mean())
    
# misclassification error / ERROR
MSE = [i-x for x in cv_scores]

# k with least error
optimal_k = nbrs[MSE.index(min(MSE))]
print("Optimal value of K is %d"%(optimal_k))
# Out:
# Optimal value of K is 1

# %% [markdown]
# #### Plot results

# %%
plt.figure(figsize=(15,15))
plt.plot(nbrs,MSE)

for xy in zip(nbrs,np.round(MSE,3)):
    plt.annotate('(%s,%s)' % xy, xy=xy, textcoords='data')

plt.xlabel("K (No of nearest neighbors)")
plt.ylabel("Error")
# Out:
# Text(0, 0.5, 'Error')

# %% [markdown]
# ## From above 10-fold cross val
# ##### Best K = 1
# ##### Test Accuracy : 80%
# ##### CV Accuracy : 70%
