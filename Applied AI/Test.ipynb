# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iris = pd.read_csv("datasets/iris.data")
haberman = pd.read_csv("datasets/haberman.csv")
iris.head(3)

# %%
haberman.head(2)
# Out:
#    age  op_year  lymph_nodes  survival
# 0   30       64            1         1
# 1   30       62            3         1

# %%
sns.FacetGrid(iris,hue="species",height=5).map(sns.distplot,'petal_length').add_legend()

# %%
sns.FacetGrid(haberman,hue="survival",height=5).map(sns.distplot,'lymph_nodes').add_legend()

# %%
def chance(k):
